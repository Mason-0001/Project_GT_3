# %%
from flask import Flask, render_template, redirect, jsonify
from flask_pymongo import PyMongo
import csv
import sqlite3
import pandas as pd
from sqlalchemy import create_engine

# %%
table_df = pd.read_json("http://127.0.0.1:5000/api/test")
table_df.head()
# Out:
#    closs       date  dy     elat      elon   f1  f2  f3  f4  fat  ...  \
# 0      0 2016-10-12  12  41.6557  -86.2886  141   0   0   0    0  ...
# 1      0 2016-10-12  12  41.6689  -86.2300  141   0   0   0    0  ...
# 2      0 2016-10-14  14  45.7200 -123.9400   57   0   0   0    0  ...
# 3      0 2016-10-14  14  45.4700 -123.9700   57   0   0   0    0  ...
# 4      0 2016-10-04   4  39.2482  -97.4066  143   0   0   0    0  ...
#
#       slat      slon  sn  st  stf  stn      time  tz  wid    yr
# 0  41.6421  -86.3046   1  IN   18    0  16:26:00   3   30  2016
# 1  41.6685  -86.2307   1  IN   18    0  16:30:00   3   40  2016
# 2  45.7200 -123.9400   1  OR   41    0   9:18:00   3  225  2016
# 3  45.4700 -123.9700   1  OR   41    0  10:00:00   3   10  2016
# 4  39.2482  -97.4066   1  KS   20    0  16:32:00   3   40  2016
#
# [5 rows x 30 columns]

# %%
table_reduced_df = table_df[["yr", "st", "mag", "loss", "fat", "inj", "len", "wid"]]
table_reduced_df.head()
# Out:
#      yr  st  mag     loss  fat  inj   len  wid
# 0  2016  IN    0        0    0    0  1.25   30
# 1  2016  IN    0        0    0    0  0.05   40
# 2  2016  OR    2  1000000    0    0  0.70  225
# 3  2016  OR   -9        0    0    0  0.01   10
# 4  2016  KS    0        0    0    0  0.10   40

# %%
table_counts = table_reduced_df.groupby("yr").count()
table_counts
year_total = table_counts.loc[(table_counts.index == 2017):]
year_total
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20752\4095909898.py in <module>
#       1 table_counts = table_reduced_df.groupby("yr").count()
#       2 table_counts
# ----> 3 year_total = table_counts.loc[(table_counts.index == 2017):]
#       4 year_total
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
# ...

# %%
nado_data = {
        "total_tornados": year_total
#         "news_article": news_article,
#         "featured_image": featured_image,
#         "featured_image_url": featured_image_url,
#         "mars_table": mars_table,
#         "hemispheres": hemi_dict_list
    }

nado_data
# Out:
# {'total_tornados': yr
#  2017    1428
#  Name: st, dtype: int64}

# %%
# Path to SQLite file
database_path = "data/tornado_db.sqlite"

# Creating the SQL database
engine = create_engine(f"sqlite:///{database_path}")

# Establisting a connection to our database
conn = engine.connect()





# response = tornado_df.to_dict(orient="records")

# %%
year_total = pd.read_sql("SELECT COUNT(*) as Total from tornado where [yr] = 2017", conn)
year_total
# Out:
#    Total
# 0   1428

# %%
nado_data = {
        "total_tornados": year_total
#         "news_article": news_article,
#         "featured_image": featured_image,
#         "featured_image_url": featured_image_url,
#         "mars_table": mars_table,
#         "hemispheres": hemi_dict_list
    }

nado_data
# Out:
# {'total_tornados':    Total
#  0   1428}
